# %% [markdown]
# <a href="https://colab.research.google.com/github/O-suke12/NLP/blob/main/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchtext
from torchtext.datasets import AG_NEWS
import time
import random
import pandas as pd
from google.colab import files
import os

# %%
RANDOM_SEED = 100
torch.manual_seed(RANDOM_SEED)

VOCABULARY_SIZE = 20000
LEARNING_RATE = 0.001
BATCH_SIZE = 64
EPOCHS = 10

EMBEDING_DIM = 128
HIDDEN_DIM = 256
NUM_CLASSES = 2

# %% [markdown]
# # **Dataset**

# %%
if os.path.exists("kaggle.json"):
  print("already exist")
else:
  uploaded = files.upload()
  ! mkdir ~/.kaggle
  ! cp kaggle.json ~/.kaggle/
  ! chmod 600 ~/.kaggle/kaggle.json
  ! kaggle datasets download -d jp797498e/twitter-entity-sentiment-analysis
  ! unzip  twitter-entity-sentiment-analysis
# Out:
#      <input type="file" id="files-6dd98cff-f242-4887-8d24-3186c522f782" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6dd98cff-f242-4887-8d24-3186c522f782">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train_data = pd.read_csv("/content/twitter_training.csv", header = None)
train_data = train_data.iloc[:, 2:].set_axis(['Evaluation', 'Comment'], axis=1)
train_data["Evaluation"] = train_data["Evaluation"].map({"Positive":1, "Negative":0})
valid_data = pd.read_csv("//content/twitter_validation.csv", header = None)
train_data.head()
# Out:
#    Evaluation                                            Comment
# 0         1.0  im getting on borderlands and i will murder yo...
# 1         1.0  I am coming to the borders and I will kill you...
# 2         1.0  im getting on borderlands and i will kill you ...
# 3         1.0  im coming on borderlands and i will murder you...
# 4         1.0  im getting on borderlands 2 and i will murder ...

# %%
train_iter = iter(AG_NEWS(split="train"))
next(train_iter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-4b44578c1a0c> in <cell line: 5>()
#       3
#       4 train_iter = iter(AG_NEWS(split="train"))
# ----> 5 next(train_iter)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/datapipes/_hook_iterator.py in wrap_generator(*args, **kwargs)
#     171                         response = gen.send(None)
#     172                 else:
# --> 173                     response = gen.send(None)
#     174
#     175                 while True:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/datapipes/iter/sharding.py in __iter__(self)
#      73
#      74     def __iter__(self):
# ---> 75         for i, item in enumerate(self.source_datapipe):
#      76             if i % self.num_of_instances == self.instance_id:
#      77                 yield item
#
# ...
